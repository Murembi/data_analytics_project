# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:Murembiwanoz64%40@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %%sql
#
# SELECT
#     SUM(Land_area) as total_land_area
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('3888270.00'),)]

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area/3888270.00*100) AS  pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32')),
#  ('Cameroon', Decimal('12')),
#  ('Central African Republic', Decimal('16')),
#  ('Chad', Decimal('32')),
#  ('Congo', None),
#  ('Democratic Republic of the Congo', None),
#  ('Equatorial Guinea', Decimal('1')),
#  ('Gabon', Decimal('7')),
#  ('Sao Tome and Principe', Decimal('0'))]

# %%
#Calculate land area percentages for the Middle African countries using a subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = 'Middle Africa') * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32.06')),
#  ('Cameroon', Decimal('12.16')),
#  ('Central African Republic', Decimal('16.02')),
#  ('Chad', Decimal('32.38')),
#  ('Congo', None),
#  ('Democratic Republic of the Congo', None),
#  ('Equatorial Guinea', Decimal('0.72')),
#  ('Gabon', Decimal('6.63')),
#  ('Sao Tome and Principe', Decimal('0.02'))]

# %%
#Calculate land area percentages for all the regions using a correlated subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = g.Sub_region) * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location AS g;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('13.67')),
#  ('Algeria', Decimal('36.03')),
#  ('American Samoa', Decimal('2.77')),
#  ('Angola', Decimal('32.06')),
#  ('Anguilla', None),
#  ('Antigua and Barbuda', Decimal('0.21')),
#  ('Argentina', Decimal('17.77')),
#  ('Armenia', Decimal('0.82')),
#  ('Aruba', Decimal('0.09')),
#  ('Australia', Decimal('96.69')),
#  ('Azerbaijan', Decimal('2.37')),
#  ('Bahamas', None),
#  ('Bahrain', Decimal('0.02')),
#  ('Bangladesh', Decimal('2.73')),
#  ('Barbados', Decimal('0.21')),
#  ('Belize', Decimal('0.93')),
#  ('Benin', Decimal('1.97')),
#  ('Bermuda', Decimal('0.00')),
#  ('Bhutan', Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', None),
#  ('Botswana', Decimal('21.38')),
#  ('Brazil', Decimal('54.27')),
#  ('British Virgin Islands', Decimal('0.07')),
#  ('Brunei Darussalam', Decimal('0.14')),
#  ('Burkina Faso', Decimal('4.77')),
#  ('Burundi', Decimal('0.43')),
#  ('Cabo Verde', Decimal('0.07')),
#  ('Cambodia', Decimal('4.57')),
#  ('Cameroon', Decimal('12.16')),
#  ('Canada', Decimal('95.62')),
#  ('Cayman Islands', Decimal('0.12')),
#  ('Central African Republic', Decimal('16.02')),
#  ('Chad', Decimal('32.38')),
#  ('Chile', Decimal('4.83')),
#  ('China', Decimal('83.06')),
#  ('Colombia', Decimal('7.20')),
#  ('Comoros', Decimal('0.03')),
#  ('Congo', None),
#  ('Cook Islands', None),
#  ('Costa Rica', Decimal('2.08')),
#  ("Côte d'Ivoire", None),
#  ('Cuba', Decimal('49.92')),
#  ('Curaçao', None),
#  ('Cyprus', Decimal('0.26')),
#  ("Democratic People's Republic of Korea", None),
#  ('Democratic Republic of the Congo', None),
#  ('Djibouti', Decimal('0.39')),
#  ('Dominica', Decimal('0.36')),
#  ('Dominican Republic', Decimal('23.21')),
#  ('Ecuador', Decimal('1.61')),
#  ('Egypt', None),
#  ('El Salvador', Decimal('0.84')),
#  ('Equatorial Guinea', Decimal('0.72')),
#  ('Eritrea', Decimal('2.04')),
#  ('Eswatini', Decimal('0.65')),
#  ('Ethiopia', Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', None),
#  ('Fiji', Decimal('3.45')),
#  ('French Guiana', None),
#  ('French Polynesia', Decimal('48.09')),
#  ('Gabon', Decimal('6.63')),
#  ('Gambia', None),
#  ('Georgia', Decimal('1.99')),
#  ('Ghana', Decimal('3.97')),
#  ('Greenland', Decimal('4.38')),
#  ('Grenada', Decimal('0.16')),
#  ('Guadeloupe', None),
#  ('Guam', Decimal('21.86')),
#  ('Guatemala', Decimal('4.37')),
#  ('Guinea', Decimal('4.28')),
#  ('Guinea-Bissau', Decimal('0.49')),
#  ('Guyana', Decimal('1.28')),
#  ('Haiti', Decimal('13.24')),
#  ('Honduras', Decimal('4.56')),
#  ('India', Decimal('62.33')),
#  ('Indonesia', Decimal('48.57')),
#  ('Iran (Islamic Republic of)', None),
#  ('Iraq', Decimal('12.44')),
#  ('Israel', Decimal('0.62')),
#  ('Jamaica', Decimal('5.20')),
#  ('Japan', Decimal('3.21')),
#  ('Jordan', Decimal('2.55')),
#  ('Kazakhstan', Decimal('72.01')),
#  ('Kenya', Decimal('9.57')),
#  ('Kiribati', Decimal('32.79')),
#  ('Kuwait', Decimal('0.51')),
#  ('Kyrgyzstan', None),
#  ("Lao People's Democratic Republic", None),
#  ('Lebanon', Decimal('0.29')),
#  ('Lesotho', Decimal('1.15')),
#  ('Liberia', Decimal('1.68')),
#  ('Libya', Decimal('26.62')),
#  ('Madagascar', Decimal('9.78')),
#  ('Malawi', Decimal('1.58')),
#  ('Malaysia', Decimal('8.50')),
#  ('Maldives', Decimal('0.01')),
#  ('Mali', Decimal('21.27')),
#  ('Marshall Islands', Decimal('7.29')),
#  ('Martinique', None),
#  ('Mauritania', Decimal('17.97')),
#  ('Mauritius', Decimal('0.03')),
#  ('Mayotte', None),
#  ('Mexico', Decimal('79.28')),
#  ('Micronesia (Federated States of)', None),
#  ('Mongolia', Decimal('13.72')),
#  ('Montserrat', None),
#  ('Morocco', Decimal('6.75')),
#  ('Mozambique', Decimal('13.22')),
#  ('Myanmar', Decimal('16.89')),
#  ('Namibia', Decimal('31.06')),
#  ('Nauru', Decimal('0.81')),
#  ('Nepal', Decimal('3.01')),
#  ('New Caledonia', Decimal('3.45')),
#  ('New Zealand', Decimal('3.31')),
#  ('Nicaragua', Decimal('4.91')),
#  ('Niger', Decimal('22.09')),
#  ('Nigeria', Decimal('15.88')),
#  ('Niue', None),
#  ('Northern Mariana Islands', Decimal('18.62')),
#  ('Oman', Decimal('8.87')),
#  ('Pakistan', Decimal('16.16')),
#  ('Palau', Decimal('18.62')),
#  ('Panama', Decimal('3.02')),
#  ('Papua New Guinea', Decimal('85.51')),
#  ('Paraguay', Decimal('2.58')),
#  ('Peru', Decimal('8.31')),
#  ('Philippines', Decimal('7.71')),
#  ('Puerto Rico', Decimal('4.26')),
#  ('Qatar', Decimal('0.33')),
#  ('Republic of Korea', None),
#  ('Réunion', None),
#  ('Rwanda', Decimal('0.41')),
#  ('Saint Barthélemy', None),
#  ('Saint Helena', None),
#  ('Saint Kitts and Nevis', None),
#  ('Saint Lucia', None),
#  ('Saint Martin (French Part)', None),
#  ('Saint Pierre and Miquelon', None),
#  ('Saint Vincent and the Grenadines', None),
#  ('Samoa', Decimal('38.75')),
#  ('Sao Tome and Principe', Decimal('0.02')),
#  ('Saudi Arabia', Decimal('61.62')),
#  ('Senegal', Decimal('3.36')),
#  ('Seychelles', Decimal('0.01')),
#  ('Sierra Leone', Decimal('1.26')),
#  ('Singapore', Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', Decimal('0.02')),
#  ('Solomon Islands', Decimal('5.29')),
#  ('Somalia', Decimal('10.55')),
#  ('South Africa', Decimal('45.77')),
#  ('South Sudan', Decimal('10.62')),
#  ('Sri Lanka', Decimal('1.30')),
#  ('State of Palestine', None),
#  ('Sudan', Decimal('28.26')),
#  ('Suriname', Decimal('1.01')),
#  ('Syrian Arab Republic', Decimal('5.26')),
#  ('Tajikistan', Decimal('3.70')),
#  ('Thailand', Decimal('13.22')),
#  ('Timor-Leste', Decimal('0.38')),
#  ('Togo', Decimal('0.95')),
#  ('Tokelau', None),
#  ('Tonga', Decimal('9.98')),
#  ('Trinidad and Tobago', Decimal('2.47')),
#  ('Tunisia', Decimal('2.35')),
#  ('Türkiye', None),
#  ('Turkmenistan', Decimal('12.53')),
#  ('Turks and Caicos Islands', Decimal('0.46')),
#  ('Tuvalu', Decimal('0.42')),
#  ('Uganda', Decimal('3.37')),
#  ('United Arab Emirates', Decimal('2.04')),
#  ('United Republic of Tanzania', None),
#  ('United States of America', None),
#  ('United States Virgin Islands', None),
#  ('Uruguay', Decimal('1.14')),
#  ('Uzbekistan', Decimal('11.75')),
#  ('Vanuatu', Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', None),
#  ('Viet Nam', None),
#  ('Wallis and Futuna Islands', None),
#  ('Yemen', None),
#  ('Zambia', Decimal('12.50')),
#  ('Zimbabwe', Decimal('6.50'))]

# %%
#Calculate the total land area for each sub-region

# %%
# %%sql
#
# SELECT
#     Sub_region,
#     SUM(Land_area) AS Total_Land_Area
# FROM
#     Geographic_location
# GROUP BY
#     Sub_region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 18 rows affected.
# [('Southern Asia', Decimal('4770135.41')),
#  ('Northern Africa', Decimal('6610941.00')),
#  ('Polynesia', Decimal('7217.67')),
#  ('Middle Africa', Decimal('3888270.00')),
#  ('Caribbean', Decimal('208104.00')),
#  ('South America', Decimal('15401392.00')),
#  ('Western Asia', Decimal('3488571.67')),
#  ('Australia and New Zealand', Decimal('7953710.00')),
#  ('Central America', Decimal('2452080.00')),
#  ('Western Africa', Decimal('5735548.83')),
#  ('Northern America', Decimal('9376094.00')),
#  ('Southern Africa', Decimal('2650670.00')),
#  ('South-Eastern Asia', Decimal('3865282.00')),
#  ('Eastern Africa', Decimal('5949153.16')),
#  ('Eastern Asia', Decimal('11346499.57')),
#  ('Melanesia', Decimal('529590.00')),
#  ('Micronesia', Decimal('2470.00')),
#  ('Central Asia', Decimal('3749015.17'))]

# %%
#Calculate country land area percentages for all the regions using a subquery in the JOIN clause

# %%
# %%sql
#
# SELECT
#     geoloc.Country_name,
#     geoloc.Land_area,
#     geoloc.Sub_region,
#     (geoloc.Land_area / Land_per_region.Total_Land_Area) * 100 AS Pct_Of_Region_Land
# FROM
#     Geographic_location AS geoloc
# JOIN
#     (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS Total_Land_Area
#     FROM
#         Geographic_location
#     GROUP BY
#         Sub_region)  AS Land_per_region
#     ON
#         geoloc.Sub_region = Land_per_region.sub_Region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('652230.00'), 'Southern Asia', Decimal('13.673197')),
#  ('Algeria', Decimal('2381741.00'), 'Northern Africa', Decimal('36.027261')),
#  ('American Samoa', Decimal('200.00'), 'Polynesia', Decimal('2.770977')),
#  ('Angola', Decimal('1246700.00'), 'Middle Africa', Decimal('32.063103')),
#  ('Anguilla', None, 'Caribbean', None),
#  ('Antigua and Barbuda', Decimal('440.00'), 'Caribbean', Decimal('0.211433')),
#  ('Argentina', Decimal('2736690.00'), 'South America', Decimal('17.769108')),
#  ('Armenia', Decimal('28470.00'), 'Western Asia', Decimal('0.816093')),
#  ('Aruba', Decimal('180.00'), 'Caribbean', Decimal('0.086495')),
#  ('Australia', Decimal('7690400.00'), 'Australia and New Zealand', Decimal('96.689469')),
#  ('Azerbaijan', Decimal('82658.17'), 'Western Asia', Decimal('2.369399')),
#  ('Bahamas', None, 'Caribbean', None),
#  ('Bahrain', Decimal('780.83'), 'Western Asia', Decimal('0.022383')),
#  ('Bangladesh', Decimal('130170.00'), 'Southern Asia', Decimal('2.728853')),
#  ('Barbados', Decimal('430.00'), 'Caribbean', Decimal('0.206627')),
#  ('Belize', Decimal('22810.00'), 'Central America', Decimal('0.930231')),
#  ('Benin', Decimal('112760.00'), 'Western Africa', Decimal('1.965984')),
#  ('Bermuda', Decimal('54.00'), 'Northern America', Decimal('0.000576')),
#  ('Bhutan', Decimal('38137.50'), 'Southern Asia', Decimal('0.799506')),
#  ('Bolivia (Plurinational State of)', None, 'South America', None),
#  ('Botswana', Decimal('566730.00'), 'Southern Africa', Decimal('21.380632')),
#  ('Brazil', Decimal('8358140.00'), 'South America', Decimal('54.268731')),
#  ('British Virgin Islands', Decimal('150.00'), 'Caribbean', Decimal('0.072079')),
#  ('Brunei Darussalam', Decimal('5270.00'), 'South-Eastern Asia', Decimal('0.136342')),
#  ('Burkina Faso', Decimal('273600.00'), 'Western Africa', Decimal('4.770250')),
#  ('Burundi', Decimal('25680.00'), 'Eastern Africa', Decimal('0.431658')),
#  ('Cabo Verde', Decimal('4030.00'), 'Western Africa', Decimal('0.070264')),
#  ('Cambodia', Decimal('176520.00'), 'South-Eastern Asia', Decimal('4.566808')),
#  ('Cameroon', Decimal('472710.00'), 'Middle Africa', Decimal('12.157335')),
#  ('Canada', Decimal('8965590.00'), 'Northern America', Decimal('95.621802')),
#  ('Cayman Islands', Decimal('240.00'), 'Caribbean', Decimal('0.115327')),
#  ('Central African Republic', Decimal('622980.00'), 'Middle Africa', Decimal('16.022036')),
#  ('Chad', Decimal('1259200.00'), 'Middle Africa', Decimal('32.384582')),
#  ('Chile', Decimal('743532.00'), 'South America', Decimal('4.827693')),
#  ('China', Decimal('9424701.90'), 'Eastern Asia', Decimal('83.062638')),
#  ('Colombia', Decimal('1109500.00'), 'South America', Decimal('7.203894')),
#  ('Comoros', Decimal('1861.00'), 'Eastern Africa', Decimal('0.031282')),
#  ('Congo', None, 'Middle Africa', None),
#  ('Cook Islands', None, 'Polynesia', None),
#  ('Costa Rica', Decimal('51060.00'), 'Central America', Decimal('2.082314')),
#  ("Côte d'Ivoire", None, 'Western Africa', None),
#  ('Cuba', Decimal('103890.00'), 'Caribbean', Decimal('49.922154')),
#  ('Curaçao', None, 'Caribbean', None),
#  ('Cyprus', Decimal('9240.00'), 'Western Asia', Decimal('0.264865')),
#  ("Democratic People's Republic of Korea", None, 'Eastern Asia', None),
#  ('Democratic Republic of the Congo', None, 'Middle Africa', None),
#  ('Djibouti', Decimal('23180.00'), 'Eastern Africa', Decimal('0.389635')),
#  ('Dominica', Decimal('750.00'), 'Caribbean', Decimal('0.360397')),
#  ('Dominican Republic', Decimal('48310.00'), 'Caribbean', Decimal('23.214354')),
#  ('Ecuador', Decimal('248360.00'), 'South America', Decimal('1.612582')),
#  ('Egypt', None, 'Northern Africa', None),
#  ('El Salvador', Decimal('20720.00'), 'Central America', Decimal('0.844997')),
#  ('Equatorial Guinea', Decimal('28050.00'), 'Middle Africa', Decimal('0.721401')),
#  ('Eritrea', Decimal('121083.12'), 'Eastern Africa', Decimal('2.035300')),
#  ('Eswatini', Decimal('17200.00'), 'Southern Africa', Decimal('0.648893')),
#  ('Ethiopia', Decimal('1128559.04'), 'Eastern Africa', Decimal('18.970079')),
#  ('Falkland Islands (Malvinas)', None, 'South America', None),
#  ('Fiji', Decimal('18270.00'), 'Melanesia', Decimal('3.449839')),
#  ('French Guiana', None, 'South America', None),
#  ('French Polynesia', Decimal('3471.00'), 'Polynesia', Decimal('48.090312')),
#  ('Gabon', Decimal('257670.00'), 'Middle Africa', Decimal('6.626855')),
#  ('Gambia', None, 'Western Africa', None),
#  ('Georgia', Decimal('69490.00'), 'Western Asia', Decimal('1.991933')),
#  ('Ghana', Decimal('227538.83'), 'Western Africa', Decimal('3.967168')),
#  ('Greenland', Decimal('410450.00'), 'Northern America', Decimal('4.377622')),
#  ('Grenada', Decimal('340.00'), 'Caribbean', Decimal('0.163380')),
#  ('Guadeloupe', None, 'Caribbean', None),
#  ('Guam', Decimal('540.00'), 'Micronesia', Decimal('21.862348')),
#  ('Guatemala', Decimal('107160.00'), 'Central America', Decimal('4.370167')),
#  ('Guinea', Decimal('245720.00'), 'Western Africa', Decimal('4.284158')),
#  ('Guinea-Bissau', Decimal('28120.00'), 'Western Africa', Decimal('0.490276')),
#  ('Guyana', Decimal('196850.00'), 'South America', Decimal('1.278131')),
#  ('Haiti', Decimal('27560.00'), 'Caribbean', Decimal('13.243378')),
#  ('Honduras', Decimal('111890.00'), 'Central America', Decimal('4.563065')),
#  ('India', Decimal('2973190.00'), 'Southern Asia', Decimal('62.329258')),
#  ('Indonesia', Decimal('1877519.00'), 'South-Eastern Asia', Decimal('48.573920')),
#  ('Iran (Islamic Republic of)', None, 'Southern Asia', None),
#  ('Iraq', Decimal('434128.00'), 'Western Asia', Decimal('12.444291')),
#  ('Israel', Decimal('21640.00'), 'Western Asia', Decimal('0.620311')),
#  ('Jamaica', Decimal('10830.00'), 'Caribbean', Decimal('5.204129')),
#  ('Japan', Decimal('364500.00'), 'Eastern Asia', Decimal('3.212444')),
#  ('Jordan', Decimal('88784.67'), 'Western Asia', Decimal('2.545015')),
#  ('Kazakhstan', Decimal('2699700.00'), 'Central Asia', Decimal('72.010912')),
#  ('Kenya', Decimal('569140.00'), 'Eastern Africa', Decimal('9.566740')),
#  ('Kiribati', Decimal('810.00'), 'Micronesia', Decimal('32.793522')),
#  ('Kuwait', Decimal('17820.00'), 'Western Asia', Decimal('0.510811')),
#  ('Kyrgyzstan', None, 'Central Asia', None),
#  ("Lao People's Democratic Republic", None, 'South-Eastern Asia', None),
#  ('Lebanon', Decimal('10230.00'), 'Western Asia', Decimal('0.293243')),
#  ('Lesotho', Decimal('30360.00'), 'Southern Africa', Decimal('1.145371')),
#  ('Liberia', Decimal('96320.00'), 'Western Africa', Decimal('1.679351')),
#  ('Libya', Decimal('1759540.00'), 'Northern Africa', Decimal('26.615576')),
#  ('Madagascar', Decimal('581800.00'), 'Eastern Africa', Decimal('9.779543')),
#  ('Malawi', Decimal('94280.00'), 'Eastern Africa', Decimal('1.584763')),
#  ('Malaysia', Decimal('328550.00'), 'South-Eastern Asia', Decimal('8.500027')),
#  ('Maldives', Decimal('300.00'), 'Southern Asia', Decimal('0.006289')),
#  ('Mali', Decimal('1220190.00'), 'Western Africa', Decimal('21.274163')),
#  ('Marshall Islands', Decimal('180.00'), 'Micronesia', Decimal('7.287449')),
#  ('Martinique', None, 'Caribbean', None),
#  ('Mauritania', Decimal('1030700.00'), 'Western Africa', Decimal('17.970381')),
#  ('Mauritius', Decimal('2030.00'), 'Eastern Africa', Decimal('0.034123')),
#  ('Mayotte', None, 'Eastern Africa', None),
#  ('Mexico', Decimal('1943950.00'), 'Central America', Decimal('79.277593')),
#  ('Micronesia (Federated States of)', None, 'Micronesia', None),
#  ('Mongolia', Decimal('1557297.67'), 'Eastern Asia', Decimal('13.724917')),
#  ('Montserrat', None, 'Caribbean', None),
#  ('Morocco', Decimal('446300.00'), 'Northern Africa', Decimal('6.750930')),
#  ('Mozambique', Decimal('786380.00'), 'Eastern Africa', Decimal('13.218352')),
#  ('Myanmar', Decimal('652780.00'), 'South-Eastern Asia', Decimal('16.888289')),
#  ('Namibia', Decimal('823290.00'), 'Southern Africa', Decimal('31.059694')),
#  ('Nauru', Decimal('20.00'), 'Micronesia', Decimal('0.809717')),
#  ('Nepal', Decimal('143350.00'), 'Southern Asia', Decimal('3.005156')),
#  ('New Caledonia', Decimal('18280.00'), 'Melanesia', Decimal('3.451727')),
#  ('New Zealand', Decimal('263310.00'), 'Australia and New Zealand', Decimal('3.310531')),
#  ('Nicaragua', Decimal('120340.00'), 'Central America', Decimal('4.907670')),
#  ('Niger', Decimal('1266700.00'), 'Western Africa', Decimal('22.085070')),
#  ('Nigeria', Decimal('910770.00'), 'Western Africa', Decimal('15.879387')),
#  ('Niue', None, 'Polynesia', None),
#  ('Northern Mariana Islands', Decimal('460.00'), 'Micronesia', Decimal('18.623482')),
#  ('Oman', Decimal('309500.00'), 'Western Asia', Decimal('8.871826')),
#  ('Pakistan', Decimal('770880.00'), 'Southern Asia', Decimal('16.160548')),
#  ('Palau', Decimal('460.00'), 'Micronesia', Decimal('18.623482')),
#  ('Panama', Decimal('74150.00'), 'Central America', Decimal('3.023963')),
#  ('Papua New Guinea', Decimal('452860.00'), 'Melanesia', Decimal('85.511433')),
#  ('Paraguay', Decimal('397300.00'), 'South America', Decimal('2.579637')),
#  ('Peru', Decimal('1280000.00'), 'South America', Decimal('8.310937')),
#  ('Philippines', Decimal('298170.00'), 'South-Eastern Asia', Decimal('7.714056')),
#  ('Puerto Rico', Decimal('8870.00'), 'Caribbean', Decimal('4.262292')),
#  ('Qatar', Decimal('11490.00'), 'Western Asia', Decimal('0.329361')),
#  ('Republic of Korea', None, 'Eastern Asia', None),
#  ('Réunion', None, 'Eastern Africa', None),
#  ('Rwanda', Decimal('24670.00'), 'Eastern Africa', Decimal('0.414681')),
#  ('Saint Barthélemy', None, 'Caribbean', None),
#  ('Saint Helena', None, 'Western Africa', None),
#  ('Saint Kitts and Nevis', None, 'Caribbean', None),
#  ('Saint Lucia', None, 'Caribbean', None),
#  ('Saint Martin (French Part)', None, 'Caribbean', None),
#  ('Saint Pierre and Miquelon', None, 'Northern America', None),
#  ('Saint Vincent and the Grenadines', None, 'Caribbean', None),
#  ('Samoa', Decimal('2796.67'), 'Polynesia', Decimal('38.747546')),
#  ('Sao Tome and Principe', Decimal('960.00'), 'Middle Africa', Decimal('0.024690')),
#  ('Saudi Arabia', Decimal('2149690.00'), 'Western Asia', Decimal('61.620921')),
#  ('Senegal', Decimal('192530.00'), 'Western Africa', Decimal('3.356784')),
#  ('Seychelles', Decimal('460.00'), 'Eastern Africa', Decimal('0.007732')),
#  ('Sierra Leone', Decimal('72180.00'), 'Western Africa', Decimal('1.258467')),
#  ('Singapore', Decimal('713.00'), 'South-Eastern Asia', Decimal('0.018446')),
#  ('Sint Maarten (Dutch part)', Decimal('34.00'), 'Caribbean', Decimal('0.016338')),
#  ('Solomon Islands', Decimal('27990.00'), 'Melanesia', Decimal('5.285221')),
#  ('Somalia', Decimal('627340.00'), 'Eastern Africa', Decimal('10.545030')),
#  ('South Africa', Decimal('1213090.00'), 'Southern Africa', Decimal('45.765410')),
#  ('South Sudan', Decimal('631930.00'), 'Eastern Africa', Decimal('10.622184')),
#  ('Sri Lanka', Decimal('61877.91'), 'Southern Asia', Decimal('1.297194')),
#  ('State of Palestine', None, 'Western Asia', None),
#  ('Sudan', Decimal('1868000.00'), 'Northern Africa', Decimal('28.256189')),
#  ('Suriname', Decimal('156000.00'), 'South America', Decimal('1.012895')),
#  ('Syrian Arab Republic', Decimal('183630.00'), 'Western Asia', Decimal('5.263759')),
#  ('Tajikistan', Decimal('138790.00'), 'Central Asia', Decimal('3.702039')),
#  ('Thailand', Decimal('510890.00'), 'South-Eastern Asia', Decimal('13.217406')),
#  ('Timor-Leste', Decimal('14870.00'), 'South-Eastern Asia', Decimal('0.384707')),
#  ('Togo', Decimal('54390.00'), 'Western Africa', Decimal('0.948296')),
#  ('Tokelau', None, 'Polynesia', None),
#  ('Tonga', Decimal('720.00'), 'Polynesia', Decimal('9.975518')),
#  ('Trinidad and Tobago', Decimal('5130.00'), 'Caribbean', Decimal('2.465114')),
#  ('Tunisia', Decimal('155360.00'), 'Northern Africa', Decimal('2.350044')),
#  ('Türkiye', None, 'Western Asia', None),
#  ('Turkmenistan', Decimal('469930.00'), 'Central Asia', Decimal('12.534759')),
#  ('Turks and Caicos Islands', Decimal('950.00'), 'Caribbean', Decimal('0.456503')),
#  ('Tuvalu', Decimal('30.00'), 'Polynesia', Decimal('0.415647')),
#  ('Uganda', Decimal('200520.00'), 'Eastern Africa', Decimal('3.370564')),
#  ('United Arab Emirates', Decimal('71020.00'), 'Western Asia', Decimal('2.035790')),
#  ('United Republic of Tanzania', None, 'Eastern Africa', None),
#  ('United States of America', None, 'Northern America', None),
#  ('United States Virgin Islands', None, 'Caribbean', None),
#  ('Uruguay', Decimal('175020.00'), 'South America', Decimal('1.136391')),
#  ('Uzbekistan', Decimal('440595.17'), 'Central Asia', Decimal('11.752291')),
#  ('Vanuatu', Decimal('12190.00'), 'Melanesia', Decimal('2.301781')),
#  ('Venezuela (Bolivarian Republic of)', None, 'South America', None),
#  ('Viet Nam', None, 'South-Eastern Asia', None),
#  ('Wallis and Futuna Islands', None, 'Polynesia', None),
#  ('Yemen', None, 'Western Asia', None),
#  ('Zambia', Decimal('743390.00'), 'Eastern Africa', Decimal('12.495728')),
#  ('Zimbabwe', Decimal('386850.00'), 'Eastern Africa', Decimal('6.502606'))]

# %%
#subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns:
#Country_name, Avg_GDP, Avg_Population.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'LIMIT 5' at line 1")
# [SQL: LIMIT 5;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', Decimal('20.14'), Decimal('38.972230')),
#  ('Argentina', Decimal('385.54'), Decimal('45.376763')),
#  ('Armenia', Decimal('12.64'), Decimal('2.805608')),
#  ('Australia', Decimal('1326.90'), Decimal('25.655289')),
#  ('Azerbaijan', Decimal('42.69'), Decimal('10.093121'))]

# %%
#Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('19.063333'), Decimal('36.2436061667')),
#  ('Algeria', Decimal('164.633333'), Decimal('41.5171783333')),
#  ('American Samoa', Decimal('0.660000'), Decimal('0.0488688333')),
#  ('Angola', Decimal('67.791667'), Decimal('30.7577836667')),
#  ('Anguilla', None, None),
#  ('Antigua and Barbuda', Decimal('1.416667'), Decimal('0.0905413333')),
#  ('Argentina', Decimal('525.670000'), Decimal('44.2628536667')),
#  ('Armenia', Decimal('11.891667'), Decimal('2.8431866667')),
#  ('Aruba', Decimal('2.970000'), Decimal('0.1045655000')),
#  ('Australia', Decimal('1338.516667'), Decimal('24.7605421667')),
#  ('Azerbaijan', Decimal('44.963333'), Decimal('9.8863935000')),
#  ('Bahamas', None, None),
#  ('Bahrain', Decimal('34.986667'), Decimal('1.4479390000')),
#  ('Bangladesh', Decimal('300.098333'), Decimal('162.6716105000')),
#  ('Barbados', Decimal('4.936667'), Decimal('0.2794133333')),
#  ('Belize', Decimal('2.261667'), Decimal('0.3779931667')),
#  ('Benin', Decimal('13.368333'), Decimal('11.7773161667')),
#  ('Bermuda', Decimal('7.038333'), Decimal('0.0642310000')),
#  ('Bhutan', Decimal('2.321667'), Decimal('0.7585361667')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('15.563333'), Decimal('2.4261566667')),
#  ('Brazil', Decimal('1816.700000'), Decimal('209.2830861667')),
#  ('British Virgin Islands', None, Decimal('0.0301700000')),
#  ('Brunei Darussalam', Decimal('12.585000'), Decimal('0.4319590000')),
#  ('Burkina Faso', Decimal('14.795000'), Decimal('20.1160605000')),
#  ('Burundi', Decimal('2.723333'), Decimal('11.3957675000')),
#  ('Cabo Verde', Decimal('1.780000'), Decimal('0.5677310000')),
#  ('Cambodia', Decimal('22.963333'), Decimal('15.9171066667')),
#  ('Cameroon', Decimal('37.088333'), Decimal('24.7446053333')),
#  ('Canada', Decimal('1641.090000'), Decimal('36.8435248333')),
#  ('Cayman Islands', Decimal('4.810000'), Decimal('0.0615830000')),
#  ('Central African Republic', Decimal('2.061667'), Decimal('5.0612291667')),
#  ('Chad', Decimal('10.720000'), Decimal('15.3657533333')),
#  ('Chile', Decimal('265.811667'), Decimal('18.5606383333')),
#  ('China', Decimal('12911.278333'), Decimal('1397.5783333333')),
#  ('Colombia', Decimal('302.633333'), Decimal('48.9153971667')),
#  ('Comoros', Decimal('1.090000'), Decimal('0.7610822000')),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('60.801667'), Decimal('5.0137766667')),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('97.696667'), Decimal('11.3273250000')),
#  ('Curaçao', None, None),
#  ('Cyprus', Decimal('23.410000'), Decimal('1.2131480000')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('2.826667'), Decimal('1.0485168333')),
#  ('Dominica', Decimal('0.546667'), Decimal('0.0701616667')),
#  ('Dominican Republic', Decimal('80.033333'), Decimal('10.7046241667')),
#  ('Ecuador', Decimal('103.081667'), Decimal('16.8800730000')),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('25.011667'), Decimal('6.2662533333')),
#  ('Equatorial Guinea', Decimal('12.210000'), Decimal('1.3988646667')),
#  ('Eritrea', None, Decimal('3.3526465000')),
#  ('Eswatini', Decimal('4.238333'), Decimal('1.1564243333')),
#  ('Ethiopia', Decimal('84.750000'), Decimal('109.7340026667')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('5.083333'), Decimal('0.9187455000')),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('5.751667'), Decimal('0.2966701667')),
#  ('Gabon', Decimal('15.396667'), Decimal('2.1637180000')),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('16.206667'), Decimal('3.7250351667')),
#  ('Ghana', Decimal('61.945000'), Decimal('30.5368060000')),
#  ('Greenland', Decimal('2.865000'), Decimal('0.0561810000')),
#  ('Grenada', Decimal('1.063333'), Decimal('0.1199556667')),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('6.005000'), Decimal('0.1685771667')),
#  ('Guatemala', Decimal('71.336667'), Decimal('16.2153060000')),
#  ('Guinea', Decimal('11.198333'), Decimal('12.4058880000')),
#  ('Guinea-Bissau', Decimal('1.325000'), Decimal('1.9024228333')),
#  ('Guyana', Decimal('4.823333'), Decimal('0.7764731667')),
#  ('Haiti', Decimal('14.936667'), Decimal('10.9368015000')),
#  ('Honduras', Decimal('23.138333'), Decimal('9.7092645000')),
#  ('India', Decimal('2542.005000'), Decimal('1360.7001680000')),
#  ('Indonesia', Decimal('1004.735000'), Decimal('265.6581158333')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('194.328333'), Decimal('40.1313536667')),
#  ('Israel', Decimal('362.698333'), Decimal('8.7985500000')),
#  ('Jamaica', Decimal('14.741667'), Decimal('2.8085933333')),
#  ('Japan', Decimal('4930.120000'), Decimal('126.8156666667')),
#  ('Jordan', Decimal('42.105000'), Decimal('10.2935920000')),
#  ('Kazakhstan', Decimal('170.095000'), Decimal('18.1534046667')),
#  ('Kenya', Decimal('86.705000'), Decimal('49.4308048333')),
#  ('Kiribati', Decimal('0.183333'), Decimal('0.1214245000')),
#  ('Kuwait', Decimal('120.840000'), Decimal('4.2000768333')),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('48.778333'), Decimal('6.0270800000')),
#  ('Lesotho', Decimal('2.335000'), Decimal('2.1851381667')),
#  ('Liberia', Decimal('3.300000'), Decimal('4.8462201667')),
#  ('Libya', Decimal('60.346667'), Decimal('6.4255858333')),
#  ('Madagascar', Decimal('12.876667'), Decimal('26.5212078333')),
#  ('Malawi', Decimal('8.971667'), Decimal('18.1396690000')),
#  ('Malaysia', Decimal('330.505000'), Decimal('32.1623901667')),
#  ('Maldives', Decimal('4.650000'), Decimal('0.4784966667')),
#  ('Mali', Decimal('15.720000'), Decimal('19.6416883333')),
#  ('Marshall Islands', Decimal('0.213333'), Decimal('0.0465093333')),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('7.220000'), Decimal('4.2185483333')),
#  ('Mauritius', Decimal('13.148333'), Decimal('1.2645741667')),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1165.201667'), Decimal('123.2676416667')),
#  ('Micronesia (Federated States of)', None, None),
#  ('Mongolia', Decimal('12.496667'), Decimal('3.1301816667')),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('119.688333'), Decimal('35.7060880000')),
#  ('Mozambique', Decimal('14.230000'), Decimal('28.9994820000')),
#  ('Myanmar', Decimal('66.593333'), Decimal('52.4656771667')),
#  ('Namibia', Decimal('11.960000'), Decimal('2.3853353333')),
#  ('Nauru', Decimal('0.108333'), Decimal('0.0117791667')),
#  ('Nepal', Decimal('29.763333'), Decimal('28.3904620000')),
#  ('New Caledonia', Decimal('9.226667'), Decimal('0.2706700000')),
#  ('New Zealand', Decimal('201.771667'), Decimal('4.8511833333')),
#  ('Nicaragua', Decimal('13.010000'), Decimal('6.5267361667')),
#  ('Niger', Decimal('11.790000'), Decimal('22.1903131667')),
#  ('Nigeria', Decimal('429.248333'), Decimal('196.0296905000')),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', Decimal('1.236000'), Decimal('0.0505208333')),
#  ('Oman', Decimal('81.696667'), Decimal('4.4798373333')),
#  ('Pakistan', Decimal('316.811667'), Decimal('218.5158821667')),
#  ('Palau', Decimal('0.280000'), Decimal('0.0178665000')),
#  ('Panama', Decimal('60.015000'), Decimal('4.1286135000')),
#  ('Papua New Guinea', Decimal('22.988333'), Decimal('9.2195820000')),
#  ('Paraguay', Decimal('37.481667'), Decimal('6.3986696667')),
#  ('Peru', Decimal('207.558333'), Decimal('31.9639481667')),
#  ('Philippines', Decimal('339.828333'), Decimal('107.6309581667')),
#  ('Puerto Rico', Decimal('103.380000'), Decimal('3.3122960000')),
#  ('Qatar', Decimal('163.025000'), Decimal('2.6759743333')),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('9.443333'), Decimal('12.3862325000')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Samoa', Decimal('0.866667'), Decimal('0.2088800000')),
#  ('Sao Tome and Principe', Decimal('0.393333'), Decimal('0.2097293333')),
#  ('Saudi Arabia', Decimal('718.561667'), Decimal('34.5336403333')),
#  ('Senegal', Decimal('21.470000'), Decimal('15.3795233333')),
#  ('Seychelles', Decimal('1.560000'), Decimal('0.0956652000')),
#  ('Sierra Leone', Decimal('3.973333'), Decimal('7.7713883333')),
#  ('Singapore', Decimal('344.631667'), Decimal('5.6304316667')),
#  ('Sint Maarten (Dutch part)', Decimal('1.233333'), Decimal('0.0397893333')),
#  ('Solomon Islands', Decimal('1.490000'), Decimal('0.6516381667')),
#  ('Somalia', Decimal('5.950000'), Decimal('15.1417306667')),
#  ('South Africa', Decimal('363.676667'), Decimal('57.1947673333')),
#  ('South Sudan', Decimal('12.000000'), Decimal('10.7279753333')),
#  ('Sri Lanka', Decimal('89.396667'), Decimal('21.5015000000')),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('68.225000'), Decimal('41.3166355000')),
#  ('Suriname', Decimal('3.828333'), Decimal('0.5909280000')),
#  ('Syrian Arab Republic', Decimal('16.718333'), Decimal('19.5595186667')),
#  ('Tajikistan', Decimal('7.833333'), Decimal('9.0305413333')),
#  ('Thailand', Decimal('470.256667'), Decimal('70.9518108333')),
#  ('Timor-Leste', Decimal('1.765000'), Decimal('1.2526480000')),
#  ('Togo', Decimal('6.418333'), Decimal('7.9532885000')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.466667'), Decimal('0.1054331667')),
#  ('Trinidad and Tobago', Decimal('23.896667'), Decimal('1.4918208333')),
#  ('Tunisia', Decimal('43.240000'), Decimal('11.8664945000')),
#  ('Türkiye', None, None),
#  ('Turkmenistan', Decimal('39.180000'), Decimal('6.0128831667')),
#  ('Turks and Caicos Islands', Decimal('1.025000'), Decimal('0.0390287500')),
#  ('Tuvalu', Decimal('0.048333'), Decimal('0.0109078333')),
#  ('Uganda', Decimal('33.035000'), Decimal('40.8703043333')),
#  ('United Arab Emirates', Decimal('387.428333'), Decimal('9.1030955000')),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('59.008333'), Decimal('3.4205535000')),
#  ('Uzbekistan', Decimal('67.808333'), Decimal('32.7173166667')),
#  ('Vanuatu', Decimal('0.856667'), Decimal('0.2938803333')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Viet Nam', None, None),
#  ('Wallis and Futuna Islands', None, None),
#  ('Yemen', None, None),
#  ('Zambia', Decimal('22.635000'), Decimal('17.5763550000')),
#  ('Zimbabwe', Decimal('22.598333'), Decimal('14.9058666667'))]

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.140000'), Decimal('38.9722300000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.3767630000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.8056080000')),
#  ('Australia', Decimal('1326.900000'), Decimal('25.6552890000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.0931210000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.7725060000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.5464020000')),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.1963040000')),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.4417250000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.0372040000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.3003150000')),
#  ('China', Decimal('14687.670000'), Decimal('1411.1000000000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.9306620000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.1231050000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.2375370000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('10.9996640000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.5885950000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.2927310000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.7227160000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.1217630000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.3871270000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.8204360000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.9287210000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.1264630000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.2657400000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.2943350000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.2711300000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.2943960000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.6186950000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.3047560000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.1463620000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('35.9971070000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.8019270000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.9190000000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.4290860000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.2320500000')),
#  ('Zambia', Decimal('18.110000'), Decimal('18.9277150000'))]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %%
#For the year 2020, which countries have a GDP above the global average,
#but still have less than 90% of their population with access to managed drinking
#water services

# %%
# %%sql
# SELECT
#     AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('274.184638'),)]

# %%
# %%sql
# SELECT
#     AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Access_to_Basic_Services
# WHERE
#     Time_period = 2020
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %%
# %%sql
# SELECT
#     AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Economic_Indicators
# WHERE
#     Time_period = 2020
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('67.00')),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('69.67')),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('72.33')),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('75.33')),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('78.00')),
#  ('Afghanistan', 2020, Decimal('20.14'), Decimal('80.33')),
#  ('Algeria', 2015, Decimal('165.98'), Decimal('92.00')),
#  ('Algeria', 2016, Decimal('160.03'), Decimal('93.00')),
#  ('Algeria', 2017, Decimal('170.10'), Decimal('93.00')),
#  ('Algeria', 2018, Decimal('174.91'), Decimal('93.00'))]

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# WHERE
#     econ.time_period = 2020
#     AND service.Pct_managed_drinking_water_services < 90
#     AND econ.Est_gdp_in_billions > (SELECT
#                                         AVG(Est_gdp_in_billions)
#                                     FROM
#                                         Economic_Indicators
#                                     WHERE
#                                         Time_period = 2020);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [('Nigeria', 2020, Decimal('432.20'), Decimal('77.33'))]

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('92.67'), Decimal('97.67'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('100.00'), Decimal('99.33'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('80.33'), Decimal('54.00'), Decimal('20.14'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.67'), Decimal('54.00'), Decimal('373.90'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('76.67'), Decimal('2.33'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'India', Decimal('91.00'), Decimal('72.33'), Decimal('2667.69'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', Decimal('96.67'), Decimal('88.33'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Maldives', Decimal('99.67'), Decimal('99.33'), Decimal('3.75'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Nepal', Decimal('90.00'), Decimal('76.67'), Decimal('33.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Pakistan', Decimal('90.67'), Decimal('70.00'), Decimal('300.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('94.33'), Decimal('93.67'), Decimal('85.35'), Decimal('338.738182')),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('93.67'), Decimal('91.67'), Decimal('14687.67'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", Decimal('93.33'), Decimal('83.33'), None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('99.00'), Decimal('100.00'), Decimal('5040.11'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('81.00'), Decimal('65.00'), Decimal('13.31'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', Decimal('100.00'), Decimal('100.00'), None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), None, Decimal('12.01'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('75.33'), Decimal('74.33'), Decimal('25.87'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('92.00'), Decimal('86.00'), Decimal('1058.69'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", Decimal('86.67'), Decimal('82.00'), None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('95.33'), Decimal('100.00'), Decimal('337.34'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('85.67'), Decimal('74.67'), Decimal('78.93'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('94.00'), Decimal('82.00'), Decimal('361.75'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('100.00'), Decimal('100.00'), Decimal('345.30'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('100.00'), Decimal('98.67'), Decimal('499.68'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', Decimal('87.00'), Decimal('60.00'), Decimal('2.16'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Viet Nam', Decimal('97.33'), Decimal('90.00'), None, Decimal('1871.901667')),
#  ('Europe and Northern America', 'Bermuda', Decimal('100.00'), Decimal('100.00'), Decimal('6.89'), Decimal('551.796667')),
#  ('Europe and Northern America', 'Canada', Decimal('99.00'), Decimal('99.00'), Decimal('1645.42'), Decimal('551.796667')),
#  ('Europe and Northern America', 'Greenland', Decimal('100.00'), Decimal('100.00'), Decimal('3.08'), Decimal('551.796667')),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', Decimal('91.00'), Decimal('100.00'), None, Decimal('551.796667')),
#  ('Europe and Northern America', 'United States of America', Decimal('100.00'), Decimal('99.67'), None, Decimal('551.796667')),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('99.00'), Decimal('98.00'), Decimal('4.67'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'British Virgin Islands', Decimal('100.00'), None, None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Cuba', Decimal('96.33'), Decimal('90.00'), Decimal('107.35'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('95.00'), Decimal('84.33'), Decimal('78.84'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Guadeloupe', Decimal('100.00'), Decimal('100.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Haiti', Decimal('65.00'), Decimal('36.00'), Decimal('14.51'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('90.33'), Decimal('87.00'), Decimal('13.81'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Martinique', Decimal('100.00'), Decimal('100.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Montserrat', Decimal('98.00'), Decimal('89.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('100.00'), Decimal('100.00'), Decimal('103.02'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', Decimal('100.00'), Decimal('100.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Saint Lucia', Decimal('97.00'), Decimal('82.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', Decimal('100.00'), Decimal('100.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', Decimal('99.00'), Decimal('94.00'), Decimal('21.06'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', Decimal('99.00'), Decimal('99.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Belize', Decimal('98.33'), Decimal('88.67'), Decimal('2.08'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('100.00'), Decimal('97.67'), Decimal('62.16'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('97.00'), Decimal('79.67'), Decimal('24.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('94.00'), Decimal('67.67'), Decimal('77.63'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('95.33'), Decimal('83.33'), Decimal('23.83'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('99.33'), Decimal('90.67'), Decimal('1090.52'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Nicaragua', Decimal('79.33'), Decimal('71.67'), Decimal('12.59'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('92.67'), Decimal('81.00'), Decimal('53.98'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Argentina', Decimal('100.00'), Decimal('99.00'), Decimal('385.54'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', Decimal('90.67'), Decimal('61.67'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('98.33'), Decimal('82.33'), Decimal('1448.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('100.00'), Decimal('100.00'), Decimal('252.73'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('94.67'), Decimal('91.33'), Decimal('270.30'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('94.00'), Decimal('91.33'), Decimal('99.29'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', Decimal('91.00'), Decimal('100.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'French Guiana', Decimal('94.00'), Decimal('92.00'), None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Guyana', Decimal('96.67'), Decimal('87.33'), Decimal('5.47'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('99.67'), Decimal('92.00'), Decimal('35.43'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('90.33'), Decimal('74.33'), Decimal('201.71'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Suriname', Decimal('98.00'), Decimal('88.67'), Decimal('2.91'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('98.00'), Decimal('98.33'), Decimal('53.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', 'Venezuela (Bolivarian Republic of)', Decimal('94.00'), Decimal('96.00'), None, Decimal('177.844400')),
#  ('Northern Africa and Western Asia', 'Algeria', Decimal('93.33'), Decimal('84.33'), Decimal('145.01'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Egypt', Decimal('99.33'), Decimal('97.67'), None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Libya', Decimal('100.00'), Decimal('92.00'), Decimal('50.36'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Morocco', Decimal('88.33'), Decimal('84.67'), Decimal('121.35'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Sudan', Decimal('62.33'), Decimal('40.33'), Decimal('27.03'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('97.00'), Decimal('97.33'), Decimal('42.54'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('100.00'), Decimal('92.33'), Decimal('12.64'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('95.67'), Decimal('96.00'), Decimal('42.69'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Bahrain', Decimal('100.00'), Decimal('100.00'), Decimal('34.72'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('100.00'), Decimal('99.33'), Decimal('25.01'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('96.67'), Decimal('84.33'), Decimal('15.84'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Iraq', Decimal('97.67'), Decimal('100.00'), Decimal('184.37'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('100.00'), Decimal('99.67'), Decimal('413.27'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('98.33'), Decimal('96.33'), Decimal('44.18'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Kuwait', Decimal('100.00'), Decimal('100.00'), Decimal('105.96'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Lebanon', Decimal('93.00'), Decimal('99.00'), Decimal('31.71'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Oman', Decimal('87.67'), Decimal('99.00'), Decimal('75.91'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('100.00'), Decimal('100.00'), Decimal('144.41'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('100.00'), Decimal('100.00'), Decimal('703.37'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'State of Palestine', Decimal('98.33'), Decimal('98.67'), None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', Decimal('93.67'), Decimal('90.00'), Decimal('11.08'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Türkiye', Decimal('96.67'), Decimal('98.67'), None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('100.00'), Decimal('99.00'), Decimal('349.47'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', 'Yemen', Decimal('63.00'), Decimal('57.33'), None, Decimal('129.046000')),
#  ('Oceania', 'Australia', Decimal('100.00'), Decimal('100.00'), Decimal('1326.90'), Decimal('93.726471')),
#  ('Oceania', 'New Zealand', Decimal('100.00'), Decimal('100.00'), Decimal('211.73'), Decimal('93.726471')),
#  ('Oceania', 'Fiji', Decimal('93.67'), Decimal('99.00'), Decimal('4.48'), Decimal('93.726471')),
#  ('Oceania', 'New Caledonia', Decimal('99.00'), Decimal('100.00'), Decimal('9.44'), Decimal('93.726471')),
#  ('Oceania', 'Papua New Guinea', Decimal('56.67'), Decimal('27.67'), Decimal('23.85'), Decimal('93.726471')),
#  ('Oceania', 'Solomon Islands', Decimal('72.33'), Decimal('44.67'), Decimal('1.54'), Decimal('93.726471')),
#  ('Oceania', 'Vanuatu', Decimal('93.00'), Decimal('55.67'), Decimal('0.90'), Decimal('93.726471')),
#  ('Oceania', 'Guam', Decimal('100.00'), None, Decimal('5.89'), Decimal('93.726471')),
#  ('Oceania', 'Kiribati', Decimal('77.00'), Decimal('45.33'), Decimal('0.18'), Decimal('93.726471')),
#  ('Oceania', 'Marshall Islands', Decimal('90.00'), Decimal('78.00'), Decimal('0.24'), Decimal('93.726471')),
#  ('Oceania', 'Nauru', Decimal('100.00'), None, Decimal('0.11'), Decimal('93.726471')),
#  ('Oceania', 'Northern Mariana Islands', Decimal('100.00'), Decimal('79.00'), None, Decimal('93.726471')),
#  ('Oceania', 'Palau', Decimal('100.00'), Decimal('99.67'), Decimal('0.25'), Decimal('93.726471')),
#  ('Oceania', 'American Samoa', Decimal('100.00'), Decimal('54.00'), Decimal('0.72'), Decimal('93.726471')),
#  ('Oceania', 'Cook Islands', Decimal('100.00'), Decimal('99.00'), None, Decimal('93.726471')),
#  ('Oceania', 'French Polynesia', Decimal('100.00'), Decimal('97.00'), Decimal('5.71'), Decimal('93.726471')),
#  ('Oceania', 'Niue', Decimal('97.00'), Decimal('96.00'), None, Decimal('93.726471')),
#  ('Oceania', 'Samoa', Decimal('92.00'), Decimal('96.33'), Decimal('0.87'), Decimal('93.726471')),
#  ('Oceania', 'Tokelau', Decimal('100.00'), Decimal('97.00'), None, Decimal('93.726471')),
#  ('Oceania', 'Tonga', Decimal('99.00'), Decimal('93.33'), Decimal('0.48'), Decimal('93.726471')),
#  ('Oceania', 'Tuvalu', Decimal('100.00'), None, Decimal('0.06'), Decimal('93.726471')),
#  ('Oceania', 'Wallis and Futuna Islands', Decimal('99.00'), Decimal('93.00'), None, Decimal('93.726471')),
#  ('Sub-Saharan Africa', 'Burundi', Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Djibouti', Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Ethiopia', Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Kenya', Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Madagascar', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Malawi', Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Mayotte', Decimal('96.00'), Decimal('100.00'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Mozambique', Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Rwanda', Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Réunion', Decimal('100.00'), Decimal('100.00'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'South Sudan', Decimal('48.33'), Decimal('22.33'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Uganda', Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', Decimal('65.00'), Decimal('34.00'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Zambia', Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Zimbabwe', Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Angola', Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Cameroon', Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Central African Republic', Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Chad', Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Congo', Decimal('69.00'), Decimal('17.67'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', Decimal('47.67'), Decimal('15.33'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Gabon', Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Botswana', Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Eswatini', Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Lesotho', Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Namibia', Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('70.67'), Decimal('34.67'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('79.33'), Decimal('44.33'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Mali', Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Mauritania', Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Niger', Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Nigeria', Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Saint Helena', Decimal('99.00'), Decimal('100.00'), None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Sierra Leone', Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Togo', Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), Decimal('39.041316'))]

# %%
# %%sql
# SELECT
#     Country_name,
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Avg_gdp_for_region
# FROM (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
#     ) AS Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Madagascar', 'Sub-Saharan Africa', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('39.041316')),
#  ('Somalia', 'Sub-Saharan Africa', Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('39.041316')),
#  ('Central African Republic', 'Sub-Saharan Africa', Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('39.041316')),
#  ('Chad', 'Sub-Saharan Africa', Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('39.041316')),
#  ('Burkina Faso', 'Sub-Saharan Africa', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('39.041316')),
#  ('Niger', 'Sub-Saharan Africa', Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('39.041316'))]

# %%
# %%sql
# -- This CTE calculates the average regional GDP for each country, for the year 2020.
# WITH Avg_world_GDP_2020 AS (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
# )
#
# /*
# This query filters the Avg_world_GDP_2020 CTE for
# countries that have below-average GDP, in the
# Sub-Saharan Africa region, and struggling with water access.
# */
#
# SELECT
#     Country_name
# FROM
#     Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Madagascar',),
#  ('Somalia',),
#  ('Central African Republic',),
#  ('Chad',),
#  ('Burkina Faso',),
#  ('Niger',)]
